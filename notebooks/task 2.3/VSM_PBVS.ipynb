# %% [markdown]
# # POSITION-BASED VISUAL SERVOING

# %% [markdown]
# ## Imports

# %%
import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt
from math import pi
from VSM_PBVS import VSM_PBVS as V_PBVS
np.set_printoptions(linewidth=120, formatter={'float': lambda x: f"{0:8.4g}" if abs(x) < 1e-10 else f"{x:8.4g}"})
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
np.random.seed(0)

# %%
from machinevisiontoolbox.base import *
from machinevisiontoolbox import *
from spatialmath.base import *
from spatialmath import *

# %% [markdown]
# ## Testing our personal PBVS

# %%
camera = CentralCamera.Default(pose = SE3.Trans(1, 1, -2));

# %%
#4 points-goal
P = mkgrid(2, 0.5)
P
# Out:
# array([[   -0.25,    -0.25,     0.25,     0.25],
#        [   -0.25,     0.25,     0.25,    -0.25],
#        [       0,        0,        0,        0]])

# %%
#image-plane projections of the world points
p = camera.project_point(P, objpose=SE3.Tz(1))
p
# Out:
# array([[   166.7,    166.7,      300,      300],
#        [   166.7,      300,      300,    166.7]])

# %%
T_Cd_G = SE3.Tz(1);

# %%
pbvs = V_PBVS(camera, P=P, pose_g=SE3.Trans(-1, -1, 2), pose_d=T_Cd_G, plotvol=[-1, 2, -1, 2, -3, 2.5]);

# %%
pbvs.run(20);
# Out:
# completed on iteration count

# %%
pbvs.plot_p();

# %%
pbvs.plot_vel();

# %%
pbvs.plot_pose();
