# %% [markdown]
# # Testing the DNN model

# %% [markdown]
# ### Imports

# %%
from machinevisiontoolbox.base import *
from machinevisiontoolbox import *
from spatialmath.base import *
from spatialmath import *

import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.transform import Rotation as R
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# ### Prepare variables

# %%
from VSM_IBVS import VSM_IBVS as V_IBVS

# Goal
P = mkgrid(2, side=0.5, pose=SE3.Tz(2));

# desired pose
camera = CentralCamera.Default(pose=SE3.Trans(1, 1, -2));
pd = 200 * np.array([[-1, -1, 1, 1], [-1, 1, 1, -1]]) + np.c_[camera.pp]

# Defining the camera with default intrinsic parameters.
camera = CentralCamera.Default(pose=SE3.Trans(1, 1, -3) * SE3.Rz(0.6));

ibvs = V_IBVS(camera, P=P, p_d=pd)
# Out:
# 2024-07-22 13:06:19.332494: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-22 13:06:19.353681: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-22 13:06:19.379058: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-22 13:06:19.387360: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-22 13:06:19.406052: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-22 13:06:21.063988: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-07-22 13:06:25.117623: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
ibvs.run(80)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# velocity: [[   209.7    183.1    226.9     24.4    148.4    27.54]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# velocity: [[  0.4781    0.333   0.4405   0.1365   0.2003   0.2024]]
# completed on iteration count

# %%
std_ibvs = IBVS(camera, P=P, p_d=pd)
std_ibvs.run(80)
# Out:
# completed on iteration count

# %%
ibvs.plot_p()

# %%
std_ibvs.plot_p()

# %%
ibvs.plot_pose()

# %%
std_ibvs.plot_pose()

# %%
ibvs.plot_vel()

# %%
std_ibvs.plot_vel()
